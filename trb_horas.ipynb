# %%
import pandas as pd
from datetime import datetime, timedelta
import holidays

# URL do arquivo CSV no GitHub (link raw)
url = 'https://github.com/alexandreLoureiro/back/blob/master/estudo.csv'

# %%
# Carregar o DataFrame a partir do link raw do GitHub
df = pd.read_csv('estudo.csv', sep=';', encoding='latin1')

# %%
df
# Out:
#       NR_TRABALHO  Total_Horas  vinculo_atividade_planejamento  \
# 0           49320         2686                           49823
# 1           49320         2686                           49812
# 2           49320         2686                           49822
# 3           49320         2686                           49824
# 4           49349         3010                           49469
# ...           ...          ...                             ...
# 1551        54036         1929                           54041
# 1552        54036         1929                           54038
# 1553        54036         1929                           54040
# 1554        54036         1929                           54042
# 1555        54036         1929                           54044
#
#       DEPE_atividade_planejamento descricao_atividade_planejamento  \
# 0                            8454        Comunicação de Resultados
# 1                            8454                    Pré-auditoria
# 2                            8454                         Execução
# 3                            8454                       Supervisão
# 4                            9647                         Execução
# ...                           ...                              ...
# 1551                         8454                         Execução
# 1552                         9889                    Pré-auditoria
# 1553                         9889                         Execução
# 1554                         9889        Comunicação de Resultados
# 1555                         9889                       Supervisão
#
#      tipo_atividade_planejamento DT_INC_atividade_planejamento  \
# 0           Processo Corporativo                     02DEC2024
# 1           Processo Corporativo                     26FEB2024
# 2           Processo Corporativo                     10/jun/24
# 3           Processo Corporativo                     26FEB2024
# 4           Processo Corporativo                     04/nov/24
# ...                          ...                           ...
# 1551        Processo Corporativo                     29SEP2025
# 1552        Processo Corporativo                     25AUG2025
# 1553        Processo Corporativo                     29SEP2025
# 1554        Processo Corporativo                     07/nov/25
# 1555        Processo Corporativo                     25AUG2025
#
#      DT_FIM_atividade_planejamento  horas_destinadas_trabalho
# 0                        04FEB2025                        420
# 1                        07/jun/24                        750
# 2                        29/nov/24                       1250
# 3                        04FEB2025                        266
# 4                        27DEC2024                         30
# ...                            ...                        ...
# 1551                     06/nov/25                        200
# 1552                     26SEP2025                        525
# 1553                     06/nov/25                        609
# 1554                     21/nov/25                        231
# 1555                     21/nov/25                        164
#
# [1556 rows x 9 columns]

# %%
# Definir feriados do Brasil
br_holidays = holidays.Brazil()

# %%
# Certifique-se de que as colunas de data estão no formato datetime
def parse_dates(date_str):
    date_formats = ['%d%b%Y', '%d/%b/%y', '%d%b%y', '%d/%m/%y', '%d/%m/%Y', '%d%b%Y', '%d%b%y', '%d%b%Y']
    for fmt in date_formats:
        try:
            return pd.to_datetime(date_str, format=fmt, dayfirst=True)
        except (ValueError, TypeError):
            continue
    return pd.NaT

# %%
# Aplicar a função de análise de datas às colunas
df['DT_INC_atividade_planejamento'] = df['DT_INC_atividade_planejamento'].apply(parse_dates)
df['DT_FIM_atividade_planejamento'] = df['DT_FIM_atividade_planejamento'].apply(parse_dates)

# Verificar se as datas foram convertidas corretamente
if df['DT_INC_atividade_planejamento'].isnull().any() or df['DT_FIM_atividade_planejamento'].isnull().any():
    print("Atenção: Algumas datas não foram convertidas corretamente. Verifique os formatos de data.")

# %%
# Obter o ano mínimo e máximo das colunas de data
min_year = df['DT_INC_atividade_planejamento'].dt.year.min()
max_year = df['DT_FIM_atividade_planejamento'].dt.year.max()

# Criar a lista de anos dinamicamente
anos = list(range(min_year, max_year + 1))

# %%
anos
# Out:
# [2024, 2025, 2026]

# %%
# Para cada ano, calcule o número de dias úteis excluindo feriados
for ano in anos:
    inicio_ano = pd.Timestamp(f'{ano}-01-01')
    fim_ano = pd.Timestamp(f'{ano}-12-31')
    
    df[f'dias_uteis_{ano}'] = df.apply(
        lambda row: len(
            pd.bdate_range(
                start=max(row['DT_INC_atividade_planejamento'], inicio_ano), 
                end=min(row['DT_FIM_atividade_planejamento'], fim_ano),
                holidays=br_holidays
            )
        ) if pd.notnull(row['DT_INC_atividade_planejamento']) and pd.notnull(row['DT_FIM_atividade_planejamento']) and min(row['DT_FIM_atividade_planejamento'], fim_ano) >= max(row['DT_INC_atividade_planejamento'], inicio_ano) else 0,
        axis=1
    )

# %%
# Calcular o total de dias úteis no período total excluindo feriados
df['total_dias_uteis'] = df.apply(
    lambda row: len(
        pd.bdate_range(
            start=row['DT_INC_atividade_planejamento'], 
            end=row['DT_FIM_atividade_planejamento'],
            holidays=br_holidays
        )
    ) if pd.notnull(row['DT_INC_atividade_planejamento']) and pd.notnull(row['DT_FIM_atividade_planejamento']) else pd.NA,
    axis=1
)

# %%
# Evitar divisão por zero
df['total_dias_uteis'] = df['total_dias_uteis'].replace({0: pd.NA})

# Calcular horas por dia útil
df['horas_por_dia_util'] = df['horas_destinadas_trabalho'] / df['total_dias_uteis']

# %%
# Para cada ano, calcular as horas trabalhadas
for ano in anos:
    df[f'horas_{ano}'] = df[f'dias_uteis_{ano}'] * df['horas_por_dia_util']
    # Substituir valores nulos por zero
    df[f'horas_{ano}'] = df[f'horas_{ano}'].fillna(0)

# Selecionar as colunas para exibição, incluindo dias úteis por ano
colunas_resultado = ['NR_TRABALHO', 'DT_INC_atividade_planejamento', 'DT_FIM_atividade_planejamento', 'horas_destinadas_trabalho', 'total_dias_uteis'] + [f'dias_uteis_{ano}' for ano in anos] + [f'horas_{ano}' for ano in anos]

# %%
df[colunas_resultado]
# Out:
#       NR_TRABALHO DT_INC_atividade_planejamento DT_FIM_atividade_planejamento  \
# 0           49320                    2024-12-02                    2025-02-04
# 1           49320                    2024-02-26                    2024-06-07
# 2           49320                    2024-06-10                    2024-11-29
# 3           49320                    2024-02-26                    2025-02-04
# 4           49349                    2024-11-04                    2024-12-27
# ...           ...                           ...                           ...
# 1551        54036                    2025-09-29                    2025-11-06
# 1552        54036                    2025-08-25                    2025-09-26
# 1553        54036                    2025-09-29                    2025-11-06
# 1554        54036                    2025-11-07                    2025-11-21
# 1555        54036                    2025-08-25                    2025-11-21
#
#       horas_destinadas_trabalho  total_dias_uteis  dias_uteis_2024  \
# 0                           420                47               22
# 1                           750                75               75
# 2                          1250               125              125
# 3                           266               247              222
# 4                            30                40               40
# ...                         ...               ...              ...
# 1551                        200                29                0
# 1552                        525                25                0
# 1553                        609                29                0
# 1554                        231                11                0
# 1555                        164                65                0
#
#       dias_uteis_2025  dias_uteis_2026   horas_2024  horas_2025  horas_2026
# 0                  25                0   196.595745  223.404255         0.0
# 1                   0                0   750.000000    0.000000         0.0
# 2                   0                0  1250.000000    0.000000         0.0
# 3                  25                0   239.076923   26.923077         0.0
# 4                   0                0    30.000000    0.000000         0.0
# ...               ...              ...          ...         ...         ...
# 1551               29                0     0.000000  200.000000         0.0
# 1552               25                0     0.000000  525.000000         0.0
# 1553               29                0     0.000000  609.000000         0.0
# 1554               11                0     0.000000  231.000000         0.0
# 1555               65                0     0.000000  164.000000         0.0
#
# [1556 rows x 11 columns]

# %%
df.query('horas_2026 > 0.0')
# Out:
#       NR_TRABALHO  Total_Horas  vinculo_atividade_planejamento  \
# 311         51886         1560                           53034
# 314         51886         1560                           51892
# 315         51886         1560                           51893
# 334         51956         1650                           51959
# 335         51956         1650                           51960
# ...           ...          ...                             ...
# 1441        53726         2230                           53744
# 1476        53808          640                           53915
# 1477        53808          640                           54057
# 1480        53809          770                           53918
# 1481        53809          770                           53919
#
#       DEPE_atividade_planejamento descricao_atividade_planejamento  \
# 311                          8960                       Supervisão
# 314                          9604        Comunicação de Resultados
# 315                          9604                       Supervisão
# 334                          8888                         Execução
# 335                          8888        Comunicação de Resultados
# ...                           ...                              ...
# 1441                         9920                       Supervisão
# 1476                         9875                       Supervisão
# 1477                         9875        Comunicação de Resultados
# 1480                         9875        Comunicação de Resultados
# 1481                         9875                       Supervisão
#
#      tipo_atividade_planejamento DT_INC_atividade_planejamento  \
# 311         Processo Corporativo                    2025-10-01
# 314         Processo Corporativo                    2025-12-15
# 315         Processo Corporativo                    2025-10-01
# 334         Processo Corporativo                    2025-11-17
# 335         Processo Corporativo                    2026-02-09
# ...                          ...                           ...
# 1441        Processo Corporativo                    2025-09-18
# 1476        Processo Corporativo                    2025-10-06
# 1477        Processo Corporativo                    2026-01-02
# 1480        Processo Corporativo                    2026-01-02
# 1481        Processo Corporativo                    2025-10-06
#
#      DT_FIM_atividade_planejamento  horas_destinadas_trabalho  \
# 311                     2026-01-09                         10
# 314                     2026-01-09                        200
# 315                     2026-01-09                         80
# 334                     2026-02-06                        900
# 335                     2026-03-14                        300
# ...                            ...                        ...
# 1441                    2026-01-09                         60
# 1476                    2026-01-15                         40
# 1477                    2026-01-15                         80
# 1480                    2026-01-22                         80
# 1481                    2026-01-22                         40
#
#       dias_uteis_2024  dias_uteis_2025  dias_uteis_2026  total_dias_uteis  \
# 311                 0               66                7                73
# 314                 0               13                7                20
# 315                 0               66                7                73
# 334                 0               33               27                60
# 335                 0                0               25                25
# ...               ...              ...              ...               ...
# 1441                0               75                7                82
# 1476                0               63               11                74
# 1477                0                0               10                10
# 1480                0                0               15                15
# 1481                0               63               16                79
#
#       horas_por_dia_util  horas_2024  horas_2025  horas_2026
# 311             0.136986         0.0    9.041096    0.958904
# 314            10.000000         0.0  130.000000   70.000000
# 315             1.095890         0.0   72.328767    7.671233
# 334            15.000000         0.0  495.000000  405.000000
# 335            12.000000         0.0    0.000000  300.000000
# ...                  ...         ...         ...         ...
# 1441            0.731707         0.0   54.878049    5.121951
# 1476            0.540541         0.0   34.054054    5.945946
# 1477            8.000000         0.0    0.000000   80.000000
# 1480            5.333333         0.0    0.000000   80.000000
# 1481            0.506329         0.0   31.898734    8.101266
#
# [111 rows x 17 columns]
